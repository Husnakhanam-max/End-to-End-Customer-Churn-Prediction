# %% [markdown]
# ## Lights, Camera, Prediction! 🎬
#
# A few snapshots of the application below. Watch how customer data is transformed into actionable churn predictions with just a few clicks.

# %% [markdown]
# ![custumer_churn_prediction_app.png](attachment:custumer_churn_prediction_app.png)

# %% [markdown]
# ![customer_churn_prediction_app (2).png](<attachment:customer_churn_prediction_app (2).png>)
